# %%
# data analysis and wrangling
import pandas as pd
import numpy as np
import random as rnd

# visualization
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# machine learning
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC, LinearSVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import Perceptron
from sklearn.linear_model import SGDClassifier
from sklearn.tree import DecisionTreeClassifier

# %%
train_ds = pd.read_csv('/Users/brianlz/Documents/DataScience/Titanic_Kaggle/DataSets/train.csv')
test_ds = pd.read_csv('/Users/brianlz/Documents/DataScience/Titanic_Kaggle/DataSets/test.csv')
combine = [train_ds, test_ds]

# %%
train_ds.describe()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>PassengerId</th>
#       <th>Survived</th>
#       <th>Pclass</th>
#       <th>Age</th>
#       <th>SibSp</th>
#       <th>Parch</th>
#       <th>Fare</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>count</th>
#       <td>891.000000</td>
#       <td>891.000000</td>
#       <td>891.000000</td>
#       <td>714.000000</td>
#       <td>891.000000</td>
#       <td>891.000000</td>
#       <td>891.000000</td>
#     </tr>
#     <tr>
#       <th>mean</th>
#       <td>446.000000</td>
#       <td>0.383838</td>
#       <td>2.308642</td>
#       <td>29.699118</td>
#       <td>0.523008</td>
# ...

# %%
train_ds[['Pclass', 'Survived']].groupby(['Pclass'], as_index=False).mean().sort_values(by='Survived', ascending=False)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Pclass</th>
#       <th>Survived</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>0.629630</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2</td>
#       <td>0.472826</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3</td>
#       <td>0.242363</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
train_ds[["Sex", "Survived"]].groupby(['Sex'], as_index=False).mean().sort_values(by='Survived', ascending=False)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Sex</th>
#       <th>Survived</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>female</td>
#       <td>0.742038</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>male</td>
#       <td>0.188908</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
g = sns.FacetGrid(train_ds, col='Survived')
g.map(plt.hist, 'Age',bins=30)

# %%
g = sns.FacetGrid(train_ds, col='Survived')
g.map(plt.hist, 'Pclass')

# %%
g = sns.FacetGrid(train_ds, col='Survived')
g.map(plt.hist, 'Embarked', bins=20)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-26-e1e9b6f76e57> in <module>()
#       1 g = sns.FacetGrid(train_ds, col='Survived')
# ----> 2 g.map(plt.hist, 'Embarked', bins=20)
#
# /Users/brianlz/PycharmProjects/Perso/venv/lib/python3.6/site-packages/seaborn/axisgrid.py in map(self, func, *args, **kwargs)
#     752
#     753             # Draw the plot
# --> 754             self._facet_plot(func, ax, plot_args, kwargs)
#     755
#     756         # Finalize the annotations and layout
#
# /Users/brianlz/PycharmProjects/Perso/venv/lib/python3.6/site-packages/seaborn/axisgrid.py in _facet_plot(self, func, ax, plot_args, plot_kwargs)
#     836
#     837         # Draw the plot
# --> 838         func(*plot_args, **plot_kwargs)
#     839
#     840         # Sort out the supporting information
#
# ...

# %%
for dataset in combine:
    dataset['Title'] = dataset.Name.str.extract(' ([A-Za-z]+)\.', expand=False)

# %%
pd.crosstab(train_ds['Title'], train_ds['Survived'])
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Survived</th>
#       <th>0</th>
#       <th>1</th>
#     </tr>
#     <tr>
#       <th>Title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Capt</th>
#       <td>1</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Col</th>
#       <td>1</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>Countess</th>
#       <td>0</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>Don</th>
#       <td>1</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Dr</th>
#       <td>4</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>Jonkheer</th>
# ...

# %%
train_ds.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>PassengerId</th>
#       <th>Survived</th>
#       <th>Pclass</th>
#       <th>Name</th>
#       <th>Sex</th>
#       <th>Age</th>
#       <th>SibSp</th>
#       <th>Parch</th>
#       <th>Ticket</th>
#       <th>Fare</th>
#       <th>Cabin</th>
#       <th>Embarked</th>
#       <th>Title</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>0</td>
#       <td>3</td>
#       <td>Braund, Mr. Owen Harris</td>
#       <td>male</td>
#       <td>22.0</td>
#       <td>1</td>
#       <td>0</td>
#       <td>A/5 21171</td>
#       <td>7.2500</td>
#       <td>NaN</td>
# ...

# %%
train_ds[['Title', 'Survived']].groupby('Title').mean()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Survived</th>
#     </tr>
#     <tr>
#       <th>Title</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Capt</th>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <th>Col</th>
#       <td>0.500000</td>
#     </tr>
#     <tr>
#       <th>Countess</th>
#       <td>1.000000</td>
#     </tr>
#     <tr>
#       <th>Don</th>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <th>Dr</th>
#       <td>0.428571</td>
#     </tr>
#     <tr>
#       <th>Jonkheer</th>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <th>Lady</th>
#       <td>1.000000</td>
#     </tr>
# ...
