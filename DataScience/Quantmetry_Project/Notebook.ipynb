# %%
import pandas as pd
import numpy as np

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('/Users/brianlz/Documents/DataScience/Projet_Quantmetry/data_v1.0.csv')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 13 columns):
# Unnamed: 0    20000 non-null int64
# index         20000 non-null int64
# date          19909 non-null object
# cheveux       19897 non-null object
# age           19909 non-null float64
# exp           19904 non-null float64
# salaire       19905 non-null float64
# sexe          19900 non-null object
# diplome       19890 non-null object
# specialite    19907 non-null object
# note          19886 non-null float64
# dispo         19894 non-null object
# embauche      20000 non-null int64
# dtypes: float64(4), int64(3), object(6)
# memory usage: 2.0+ MB

# %%
data.describe()
# Out:
#          Unnamed: 0         index           age           exp       salaire  \
# count  20000.000000  20000.000000  19909.000000  19904.000000  19905.000000
# mean    9999.500000   9999.500000     35.004521      9.500352  34974.343934
# std     5773.647028   5773.647028      9.609169      3.012109   5003.099616
# min        0.000000      0.000000     -3.000000     -2.000000  14128.000000
# 25%     4999.750000   4999.750000     29.000000      7.000000  31596.000000
# 50%     9999.500000   9999.500000     35.000000      9.000000  34979.000000
# 75%    14999.250000  14999.250000     41.000000     12.000000  38358.000000
# max    19999.000000  19999.000000     74.000000     23.000000  53977.000000
#
#                note      embauche
# count  19886.000000  20000.000000
# mean      75.168762      0.114600
# std       17.095926      0.318547
# min        8.680000      0.000000
# 25%       63.720000      0.000000
# 50%       75.080000      0.000000
# 75%       86.617500      0.000000
# ...

# %%
data.hist(column='age')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x11d527128>]],
#       dtype=object)

# %%
data.hist(column='exp')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x11d5b7c88>]],
#       dtype=object)

# %%
data.loc[(data['age']<13) | (data['exp']<0),:]
# Out:
#        Unnamed: 0  index        date  cheveux   age   exp  salaire sexe  \
# 164           164    164  2011-02-18     brun  10.0   9.0  38767.0    F
# 211           211    211  2014-05-09     brun  12.0  10.0  31557.0    F
# 258           258    258  2011-01-10  chatain   8.0  10.0  44530.0    F
# 296           296    296  2013-02-18     roux   8.0  16.0  25825.0    F
# 396           396    396  2010-02-14  chatain   8.0  11.0  36915.0    M
# 405           405    405  2013-05-01    blond  10.0   6.0  39318.0    M
# 422           422    422  2014-12-16     roux   8.0  12.0  34060.0    M
# 483           483    483  2011-06-07  chatain  12.0   2.0  29034.0    F
# 518           518    518  2012-04-15  chatain  12.0   4.0  44770.0    M
# 529           529    529  2013-12-24    blond   5.0  13.0  39079.0    M
# 826           826    826  2012-03-11    blond   5.0   8.0  31908.0    M
# 868           868    868  2011-08-07     roux   6.0  16.0  44069.0    M
# ...

# %%
data.loc[data['age']+5 < data['exp'],:]
# Out:
#        Unnamed: 0  index        date  cheveux   age   exp  salaire sexe  \
# 296           296    296  2013-02-18     roux   8.0  16.0  25825.0    F
# 529           529    529  2013-12-24    blond   5.0  13.0  39079.0    M
# 868           868    868  2011-08-07     roux   6.0  16.0  44069.0    M
# 1842         1842   1842  2012-02-25    blond  -1.0   6.0  38176.0    M
# 3640         3640   3640  2011-08-04     brun  11.0  17.0  36457.0    M
# 3700         3700   3700  2013-04-25     brun   2.0  10.0  33390.0    F
# 3940         3940   3940  2012-10-10    blond   6.0  13.0  31905.0    M
# 3968         3968   3968  2011-12-08     brun  -3.0  11.0  26167.0    M
# 6940         6940   6940  2010-10-26  chatain   8.0  14.0  26885.0    F
# 8363         8363   8363  2014-07-11  chatain   4.0  12.0  36765.0    F
# 8648         8648   8648  2014-03-16    blond   2.0  16.0  29500.0    M
# 8941         8941   8941  2010-12-18     brun   4.0  11.0  37411.0    M
# ...

# %%
data[['sexe', 'embauche']].groupby(['sexe'], as_index=False).mean()
# Out:
#   sexe  embauche
# 0    F  0.102859
# 1    M  0.122466

# %%
data[['diplome', 'embauche']].groupby(['diplome'], as_index=False).mean()
# Out:
#     diplome  embauche
# 0       bac  0.083163
# 1  doctorat  0.087554
# 2   licence  0.121594
# 3    master  0.126581

# %%
data[['dispo', 'embauche']].groupby(['dispo'], as_index=False).mean()
# Out:
#   dispo  embauche
# 0   non  0.111749
# 1   oui  0.118693

# %%
data[['cheveux', 'embauche']].groupby(['cheveux'], as_index=False).mean()
# Out:
#    cheveux  embauche
# 0    blond  0.117052
# 1     brun  0.116341
# 2  chatain  0.111093
# 3     roux  0.114578

# %%
data[['specialite', 'embauche']].groupby(['specialite'], as_index=False).mean().sort_values(by='embauche', ascending=False)
# Out:
#     specialite  embauche
# 0  archeologie  0.207370
# 3     geologie  0.117770
# 1    detective  0.101324
# 2       forage  0.091244

# %%
g = sns.FacetGrid(data, col='embauche')
g.map(plt.hist, 'salaire', bins=30)

# %%
g = sns.FacetGrid(data, col='embauche')
g.map(plt.hist, 'note', bins=30)

# %%
g = sns.FacetGrid(data, col='embauche')
g.map(plt.hist, 'age',bins=25)

# %%
g = sns.FacetGrid(data, col='embauche')
g.map(plt.hist, 'exp',bins =20)

# %%
data[['exp', 'embauche']].groupby(['exp'], as_index=False).mean()
# Out:
#      exp  embauche
# 0   -2.0  0.000000
# 1   -1.0  0.000000
# 2    0.0  0.043478
# 3    1.0  0.066667
# 4    2.0  0.090090
# 5    3.0  0.099291
# 6    4.0  0.105590
# 7    5.0  0.099885
# 8    6.0  0.120805
# 9    7.0  0.119276
# 10   8.0  0.119778
# 11   9.0  0.110690
# 12  10.0  0.116364
# 13  11.0  0.115141
# 14  12.0  0.121687
# 15  13.0  0.111275
# 16  14.0  0.112740
# 17  15.0  0.105788
# 18  16.0  0.129555
# 19  17.0  0.086614
# 20  18.0  0.145833
# 21  19.0  0.187500
# 22  20.0  0.500000
# 23  21.0  0.000000
# 24  23.0  0.000000

# %% [markdown]
# # Dépendance Significative

# %%
pd.crosstab(data['sexe'],data['specialite'])
# Out:
# specialite  archeologie  detective  forage  geologie
# sexe
# F                  1081       2522    1964      2403
# M                   298       1614    2351      7576

# %%
g = sns.FacetGrid(data, col='cheveux')
g.map(plt.hist, 'salaire', bins=20)

# %%
data.plot.scatter(x='exp',y='age',alpha=.005)

# %%
mat_corr = data.corr()
mat_corr
# Out:
#             Unnamed: 0     index       age       exp   salaire      note  \
# Unnamed: 0    1.000000  1.000000 -0.000228  0.003989  0.000209  0.003267
# index         1.000000  1.000000 -0.000228  0.003989  0.000209  0.003267
# age          -0.000228 -0.000228  1.000000 -0.002786  0.001161 -0.007534
# exp           0.003989  0.003989 -0.002786  1.000000  0.009709 -0.012195
# salaire       0.000209  0.000209  0.001161  0.009709  1.000000 -0.448422
# note          0.003267  0.003267 -0.007534 -0.012195 -0.448422  1.000000
# embauche     -0.018381 -0.018381 -0.011623  0.006604  0.002342  0.003019
#
#             embauche
# Unnamed: 0 -0.018381
# index      -0.018381
# age        -0.011623
# exp         0.006604
# salaire     0.002342
# note        0.003019
# embauche    1.000000

# %%
np.corrcoef(data['exp'],data['note'])
# Out:
# array([[nan, nan],
#        [nan, nan]])

# %%
data[['diplome', 'exp']].groupby(['diplome'], as_index=False).mean()
# Out:
#     diplome       exp
# 0       bac  9.501638
# 1  doctorat  9.492508
# 2   licence  9.498979
# 3    master  9.507027

# %%
data.plot.scatter(x='salaire',y='age',alpha=.1)

# %%
# Out:
# Score sur le jeu de Test : 0.90

# %% [markdown]
# # Machine Learning
